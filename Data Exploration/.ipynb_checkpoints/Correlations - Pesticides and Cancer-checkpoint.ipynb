# %%
#import libraries
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px

from scipy.stats import linregress

# %%
#pull in csv file
data_df = pd.read_csv("../Data Sets/cancer_and_pesticides.csv")
data_df.head()
# Out:
#                         County   FIPS  Cancer Incidence Rate Per 100k  \
# 0     Union County, Florida(6)  12125                          1237.4
# 1    Palo Alto County, Iowa(7)  19147                           658.1
# 2  Treasure County, Montana(6)  30103                           652.2
# 3        Polk County, Texas(7)  48373                           633.6
# 4    Floyd County, Kentucky(7)  21071                           616.8
#
#    Insecticide Sum  Herbicide Sum  Fungicide Sum  Adjuvant Sum
# 0            253.1         7146.6          241.5           0.0
# 1           5897.5       269873.7         4271.9           0.0
# 2            839.8        76881.9          488.3           0.0
# 3              1.2         1694.6            1.6           0.0
# 4              4.2          812.9            3.8           0.0

# %%
#Union County Florida seems to be an outlier with low pesticide use rates and very high cancer rates.
#Let's remove it to see if it is effecting correlation calculations 

filtered_data_df = data_df[data_df['County'] != 'Union County, Florida(6)']

# %% [markdown]
# ## Insecticide

# %%
#create R score for cancer incidence rate per 100k and insecticide sum

i_r_score = data_df['Cancer Incidence Rate Per 100k'].corr(data_df['Insecticide Sum'])
i_filtered_r_score = filtered_data_df['Cancer Incidence Rate Per 100k'].corr(filtered_data_df['Insecticide Sum'])
print("R score for Cancer Incidence Rate Per 100k and Insecticide Sum:", r_score)
print("Filtered R score, Cancer Incidence Rate/100k & Insecticide Sum:", filtered_r_score)
# Out:
# R score for Cancer Incidence Rate Per 100k and Insecticide Sum: -0.006236123293454189
# Filtered R score, Cancer Incidence Rate/100k & Insecticide Sum: -0.0034886085052644677

# %% [markdown]
# **Based on the above, we are proceeding with the filtered data, removing Union County, Florida**

# %%
#Create a graph with line of best fit & data points plotting cancer incidence rate per 100k and insecticide sum

# Set the style of the seaborn plot
sns.set_style("whitegrid")

# Create a scatter plot with a line of best fit
plt.figure(figsize=(10, 6))
sns.regplot(x='Insecticide Sum', y='Cancer Incidence Rate Per 100k', data=filtered_data_df, scatter_kws={'alpha':0.5},
            line_kws={'color': 'darkorange'})

# Set the title and labels for the plot
plt.title('Cancer Incidence Rate Per 100k vs. Insecticide Sum')
plt.xlabel('Insecticide Sum')
plt.ylabel('Cancer Incidence Rate Per 100k')

# Show the plot
plt.show()

# %%
#Calculate the line of best fit for  Insecticide Sum and Cancer Incidence Rate
slope, intercept, r_value, p_value, std_err = linregress(filtered_data_df['Insecticide Sum'],
                                                         filtered_data_df['Cancer Incidence Rate Per 100k'])

# Format the equation as a string
equation = f'y = {slope:.7f}x + {intercept:.2f}'
print("Equation of the line of best fit:", equation)
# Out:
# Equation of the line of best fit: y = 0.0000197x + 452.38

# %% [markdown]
# **I left the these plots the same to allow for interactive exploration by our team**

# %%
#Create an interactive plot to explore the details of the data points.
fig = px.scatter(data_df, x='Insecticide Sum', y='Cancer Incidence Rate Per 100k',
                 hover_data=['County', 'Insecticide Sum', 'Cancer Incidence Rate Per 100k'],
                 title='Cancer Incidence Rate Per 100k vs. Insecticide Sum')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="68419e56-8517-48a9-9987-8308f6bef648" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68419e56-8517-48a9-9987-8308f6bef648")) {                    Plotly.newPlot(                        "68419e56-8517-48a9-9987-8308f6bef648",                        [{"customdata":[["Union County, Florida(6)"],["Palo Alto County, Iowa(7)"],["Treasure County, Montana(6)"],["Polk County, Texas(7)"],["Floyd County, Kentucky(7)"],["Logan County, Nebraska(6)"],["Powell County, Kentucky(7)"],["Blaine County, Nebraska(6)"],["Golden Valley County, Montana(6)"],["Lincoln County, Kentucky(7)"],["Logan County, West Virginia(6)"],["Mercer County, Kentucky(7)"],["Perry County, Kentucky(7)"],["Fleming County, Kentucky(7)"],["Grant County, Kentucky(7)"],["Pickens County, Georgia(7)"],["Adams County, Wisconsin(6)"],["Owsley County, Kentucky(7)"],["Bath County, Kentucky(7)"],["Lee County, Kentucky(7)"],["Lee County, Georgia(7)"],["Monroe County, Kentucky(7)"],["Livingston County, Kentucky(7)"],["Scott County, Illinois(7)"],["Taylor County, Kentucky(7)"],["Cass County, Iowa(7)"],["Menard County, Illinois(7)"],["Clay County, Kentucky(7)"],["McDuffie County, Georgia(7)"],["Pleasants County, West Virginia(6)"],["Knox County, Kentucky(7)"],["Lawrence County, Kentucky(7)"],["Marion County, Illinois(7)"],["Hitchcock County, Nebraska(6)"],["Jefferson County, New York(7)"],["Trousdale County, Tennessee(6)"],["Bryan County, Georgia(7)"],["Iberville Parish, Louisiana(7)"],["Stonewall County, Texas(7)"],["Lewis County, West Virginia(6)"],["Harlan County, Kentucky(7)"],["Aurora County, South Dakota(6)"],["Cape May County, New Jersey(7)"],["McCook County, South Dakota(6)"],["Greeley County, Nebraska(6)"],["Adair County, Kentucky(7)"],["Montgomery County, Missouri(6)"],["Butler County, Kentucky(7)"],["Morgan County, Illinois(7)"],["Nassau County, Florida(6)"],["Burnett County, Wisconsin(6)"],["Christian County, Illinois(7)"],["Bracken County, Kentucky(7)"],["Clay County, South Dakota(6)"],["Montgomery County, Iowa(7)"],["Cherokee County, Iowa(7)"],["Logan County, Illinois(7)"],["Terrell County, Georgia(7)"],["Potter County, South Dakota(6)"],["Lawrence County, Ohio(6)"],["Niagara County, New York(7)"],["Greene County, Iowa(7)"],["Cumberland County, Kentucky(7)"],["Montour County, Pennsylvania(6)"],["Russell County, Kentucky(7)"],["Johnson County, Kentucky(7)"],["Musselshell County, Montana(6)"],["Piscataquis County, Maine(6)"],["Clay County, Illinois(7)"],["Orleans County, New York(7)"],["Turner County, Georgia(7)"],["Haakon County, South Dakota(6)"],["East Carroll Parish, Louisiana(7)"],["Pike County, Kentucky(7)"],["Cerro Gordo County, Iowa(7)"],["McLean County, Kentucky(7)"],["Macon County, Illinois(7)"],["Mississippi County, Missouri(6)"],["Prairie County, Montana(6)"],["Breathitt County, Kentucky(7)"],["Grundy County, Illinois(7)"],["St. Landry Parish, Louisiana(7)"],["Whitley County, Kentucky(7)"],["Owen County, Kentucky(7)"],["Buffalo County, South Dakota(6)"],["Rosebud County, Montana(6)"],["Pike County, Illinois(7)"],["Marion County, Kentucky(7)"],["Franklin County, Iowa(7)"],["Estill County, Kentucky(7)"],["Foard County, Texas(7)"],["Pocahontas County, Iowa(7)"],["Onslow County, North Carolina(6)"],["Oswego County, New York(7)"],["Houston County, Tennessee(6)"],["Sangamon County, Illinois(7)"],["Hernando County, Florida(6)"],["Grenada County, Mississippi(6)"],["Harrison County, Kentucky(7)"],["Tishomingo County, Mississippi(6)"],["Wolfe County, Kentucky(7)"],["Shelby County, Illinois(7)"],["Kingsbury County, South Dakota(6)"],["Carter County, Kentucky(7)"],["Humphreys County, Tennessee(6)"],["Lincoln County, West Virginia(6)"],["Webster County, West Virginia(6)"],["Cortland County, New York ...

# %% [markdown]
# ## Herbicide

# %%
#create R score for cancer incidence rate per 100k and herbicide sum

h_r_score = data_df['Cancer Incidence Rate Per 100k'].corr(data_df['Herbicide Sum'])
print("R score for Cancer Incidence Rate Per 100k and Herbicide Sum:", r_score)

h_filtered_r_score = filtered_data_df['Cancer Incidence Rate Per 100k'].corr(data_df['Herbicide Sum'])
print("Filtered R score, Cancer Incidence Rate/100k & Herbicide Sum:", filtered_r_score)
# Out:
# R score for Cancer Incidence Rate Per 100k and Herbicide Sum: -0.006236123293454189
# Filtered R score, Cancer Incidence Rate/100k & Herbicide Sum: -0.0034886085052644677

# %%
#Create a graph with line of best fit & data points plotting cancer incidence rate per 100k and herbicide sum

# Set the style of the seaborn plot
sns.set_style("whitegrid")

# Create a scatter plot with a line of best fit
plt.figure(figsize=(10, 6))
sns.regplot(x='Herbicide Sum', y='Cancer Incidence Rate Per 100k', data=filtered_data_df, scatter_kws={'alpha':0.5},
            line_kws={'color': 'green'})

# Set the title and labels for the plot
plt.title('Cancer Incidence Rate Per 100k People vs. Herbicide Sum')
plt.xlabel('Herbicide Sum')
plt.ylabel('Cancer Incidence Rate Per 100k People')

# Show the plot
plt.show()

# %%
#Calculate the line of best fit for Herbicide Sum and Cancer Incidence Rate
slope, intercept, r_value, p_value, std_err = linregress(filtered_data_df['Herbicide Sum'],
                                                         filtered_data_df['Cancer Incidence Rate Per 100k'])

# Format the equation as a string
equation = f'y = {slope:.7f}x + {intercept:.2f}'
print("Equation of the line of best fit:", equation)
# Out:
# Equation of the line of best fit: y = 0.0000268x + 449.82

# %%
#Create an interactive plot to explore the details of the data points.
fig = px.scatter(data_df, x='Herbicide Sum', y='Cancer Incidence Rate Per 100k',
                 hover_data=['County', 'Herbicide Sum', 'Cancer Incidence Rate Per 100k'],
                 title='Cancer Incidence Rate Per 100k v. Herbicide Sum')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="907c0e92-5660-4251-a842-a811de298873" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("907c0e92-5660-4251-a842-a811de298873")) {                    Plotly.newPlot(                        "907c0e92-5660-4251-a842-a811de298873",                        [{"customdata":[["Union County, Florida(6)"],["Palo Alto County, Iowa(7)"],["Treasure County, Montana(6)"],["Polk County, Texas(7)"],["Floyd County, Kentucky(7)"],["Logan County, Nebraska(6)"],["Powell County, Kentucky(7)"],["Blaine County, Nebraska(6)"],["Golden Valley County, Montana(6)"],["Lincoln County, Kentucky(7)"],["Logan County, West Virginia(6)"],["Mercer County, Kentucky(7)"],["Perry County, Kentucky(7)"],["Fleming County, Kentucky(7)"],["Grant County, Kentucky(7)"],["Pickens County, Georgia(7)"],["Adams County, Wisconsin(6)"],["Owsley County, Kentucky(7)"],["Bath County, Kentucky(7)"],["Lee County, Kentucky(7)"],["Lee County, Georgia(7)"],["Monroe County, Kentucky(7)"],["Livingston County, Kentucky(7)"],["Scott County, Illinois(7)"],["Taylor County, Kentucky(7)"],["Cass County, Iowa(7)"],["Menard County, Illinois(7)"],["Clay County, Kentucky(7)"],["McDuffie County, Georgia(7)"],["Pleasants County, West Virginia(6)"],["Knox County, Kentucky(7)"],["Lawrence County, Kentucky(7)"],["Marion County, Illinois(7)"],["Hitchcock County, Nebraska(6)"],["Jefferson County, New York(7)"],["Trousdale County, Tennessee(6)"],["Bryan County, Georgia(7)"],["Iberville Parish, Louisiana(7)"],["Stonewall County, Texas(7)"],["Lewis County, West Virginia(6)"],["Harlan County, Kentucky(7)"],["Aurora County, South Dakota(6)"],["Cape May County, New Jersey(7)"],["McCook County, South Dakota(6)"],["Greeley County, Nebraska(6)"],["Adair County, Kentucky(7)"],["Montgomery County, Missouri(6)"],["Butler County, Kentucky(7)"],["Morgan County, Illinois(7)"],["Nassau County, Florida(6)"],["Burnett County, Wisconsin(6)"],["Christian County, Illinois(7)"],["Bracken County, Kentucky(7)"],["Clay County, South Dakota(6)"],["Montgomery County, Iowa(7)"],["Cherokee County, Iowa(7)"],["Logan County, Illinois(7)"],["Terrell County, Georgia(7)"],["Potter County, South Dakota(6)"],["Lawrence County, Ohio(6)"],["Niagara County, New York(7)"],["Greene County, Iowa(7)"],["Cumberland County, Kentucky(7)"],["Montour County, Pennsylvania(6)"],["Russell County, Kentucky(7)"],["Johnson County, Kentucky(7)"],["Musselshell County, Montana(6)"],["Piscataquis County, Maine(6)"],["Clay County, Illinois(7)"],["Orleans County, New York(7)"],["Turner County, Georgia(7)"],["Haakon County, South Dakota(6)"],["East Carroll Parish, Louisiana(7)"],["Pike County, Kentucky(7)"],["Cerro Gordo County, Iowa(7)"],["McLean County, Kentucky(7)"],["Macon County, Illinois(7)"],["Mississippi County, Missouri(6)"],["Prairie County, Montana(6)"],["Breathitt County, Kentucky(7)"],["Grundy County, Illinois(7)"],["St. Landry Parish, Louisiana(7)"],["Whitley County, Kentucky(7)"],["Owen County, Kentucky(7)"],["Buffalo County, South Dakota(6)"],["Rosebud County, Montana(6)"],["Pike County, Illinois(7)"],["Marion County, Kentucky(7)"],["Franklin County, Iowa(7)"],["Estill County, Kentucky(7)"],["Foard County, Texas(7)"],["Pocahontas County, Iowa(7)"],["Onslow County, North Carolina(6)"],["Oswego County, New York(7)"],["Houston County, Tennessee(6)"],["Sangamon County, Illinois(7)"],["Hernando County, Florida(6)"],["Grenada County, Mississippi(6)"],["Harrison County, Kentucky(7)"],["Tishomingo County, Mississippi(6)"],["Wolfe County, Kentucky(7)"],["Shelby County, Illinois(7)"],["Kingsbury County, South Dakota(6)"],["Carter County, Kentucky(7)"],["Humphreys County, Tennessee(6)"],["Lincoln County, West Virginia(6)"],["Webster County, West Virginia(6)"],["Cortland County, New York ...

# %% [markdown]
# ## Fungicide

# %%
#create R score for cancer incidence rate per 100k and fungicide sum

f_r_score = data_df['Cancer Incidence Rate Per 100k'].corr(data_df['Fungicide Sum'])
print("R score for Cancer Incidence Rate Per 100k and Herbicide Sum:", r_score)

f_filtered_r_score = filtered_data_df['Cancer Incidence Rate Per 100k'].corr(data_df['Fungicide Sum'])
print("Filtered R score, Cancer Incidence Rate/100k & Fungicide Sum:", filtered_r_score)
# Out:
# R score for Cancer Incidence Rate Per 100k and Herbicide Sum: -0.006236123293454189
# Filtered R score, Cancer Incidence Rate/100k & Fungicide Sum: -0.0034886085052644677

# %%
#Create a graph with line of best fit & data points plotting cancer incidence rate per 100k and fungicide sum

# Set the style of the seaborn plot
sns.set_style("whitegrid")

# Create a scatter plot with a line of best fit
plt.figure(figsize=(10, 6))
sns.regplot(x='Fungicide Sum', y='Cancer Incidence Rate Per 100k', data=filtered_data_df, scatter_kws={'alpha':0.5},
            line_kws={'color': 'purple'})

# Set the title and labels for the plot
plt.title('Cancer Incidence Rate Per 100k vs. Fungicide Sum')
plt.xlabel('Fungicide Sum')
plt.ylabel('Cancer Incidence Rate Per 100k People')

# Show the plot
plt.show()

# %%
#Calculate the line of best fit for Fungicide Sum and Cancer Incidence Rate
slope, intercept, r_value, p_value, std_err = linregress(filtered_data_df['Fungicide Sum'],
                                                         filtered_data_df['Cancer Incidence Rate Per 100k'])

# Format the equation as a string
equation = f'y = {slope:.7f}x + {intercept:.2f}'
print("Equation of the line of best fit:", equation)
# Out:
# Equation of the line of best fit: y = -0.0000635x + 452.57

# %%
#Create an interactive plot to explore the details of the data points.
fig = px.scatter(data_df, x='Fungicide Sum', y='Cancer Incidence Rate Per 100k',
                 hover_data=['County', 'Fungicide Sum', 'Cancer Incidence Rate Per 100k'],
                 title='Cancer Incidence Rate Per 100k v. Fungicide Sum')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="507a53d1-fde8-4399-bb1b-98508f791236" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("507a53d1-fde8-4399-bb1b-98508f791236")) {                    Plotly.newPlot(                        "507a53d1-fde8-4399-bb1b-98508f791236",                        [{"customdata":[["Union County, Florida(6)"],["Palo Alto County, Iowa(7)"],["Treasure County, Montana(6)"],["Polk County, Texas(7)"],["Floyd County, Kentucky(7)"],["Logan County, Nebraska(6)"],["Powell County, Kentucky(7)"],["Blaine County, Nebraska(6)"],["Golden Valley County, Montana(6)"],["Lincoln County, Kentucky(7)"],["Logan County, West Virginia(6)"],["Mercer County, Kentucky(7)"],["Perry County, Kentucky(7)"],["Fleming County, Kentucky(7)"],["Grant County, Kentucky(7)"],["Pickens County, Georgia(7)"],["Adams County, Wisconsin(6)"],["Owsley County, Kentucky(7)"],["Bath County, Kentucky(7)"],["Lee County, Kentucky(7)"],["Lee County, Georgia(7)"],["Monroe County, Kentucky(7)"],["Livingston County, Kentucky(7)"],["Scott County, Illinois(7)"],["Taylor County, Kentucky(7)"],["Cass County, Iowa(7)"],["Menard County, Illinois(7)"],["Clay County, Kentucky(7)"],["McDuffie County, Georgia(7)"],["Pleasants County, West Virginia(6)"],["Knox County, Kentucky(7)"],["Lawrence County, Kentucky(7)"],["Marion County, Illinois(7)"],["Hitchcock County, Nebraska(6)"],["Jefferson County, New York(7)"],["Trousdale County, Tennessee(6)"],["Bryan County, Georgia(7)"],["Iberville Parish, Louisiana(7)"],["Stonewall County, Texas(7)"],["Lewis County, West Virginia(6)"],["Harlan County, Kentucky(7)"],["Aurora County, South Dakota(6)"],["Cape May County, New Jersey(7)"],["McCook County, South Dakota(6)"],["Greeley County, Nebraska(6)"],["Adair County, Kentucky(7)"],["Montgomery County, Missouri(6)"],["Butler County, Kentucky(7)"],["Morgan County, Illinois(7)"],["Nassau County, Florida(6)"],["Burnett County, Wisconsin(6)"],["Christian County, Illinois(7)"],["Bracken County, Kentucky(7)"],["Clay County, South Dakota(6)"],["Montgomery County, Iowa(7)"],["Cherokee County, Iowa(7)"],["Logan County, Illinois(7)"],["Terrell County, Georgia(7)"],["Potter County, South Dakota(6)"],["Lawrence County, Ohio(6)"],["Niagara County, New York(7)"],["Greene County, Iowa(7)"],["Cumberland County, Kentucky(7)"],["Montour County, Pennsylvania(6)"],["Russell County, Kentucky(7)"],["Johnson County, Kentucky(7)"],["Musselshell County, Montana(6)"],["Piscataquis County, Maine(6)"],["Clay County, Illinois(7)"],["Orleans County, New York(7)"],["Turner County, Georgia(7)"],["Haakon County, South Dakota(6)"],["East Carroll Parish, Louisiana(7)"],["Pike County, Kentucky(7)"],["Cerro Gordo County, Iowa(7)"],["McLean County, Kentucky(7)"],["Macon County, Illinois(7)"],["Mississippi County, Missouri(6)"],["Prairie County, Montana(6)"],["Breathitt County, Kentucky(7)"],["Grundy County, Illinois(7)"],["St. Landry Parish, Louisiana(7)"],["Whitley County, Kentucky(7)"],["Owen County, Kentucky(7)"],["Buffalo County, South Dakota(6)"],["Rosebud County, Montana(6)"],["Pike County, Illinois(7)"],["Marion County, Kentucky(7)"],["Franklin County, Iowa(7)"],["Estill County, Kentucky(7)"],["Foard County, Texas(7)"],["Pocahontas County, Iowa(7)"],["Onslow County, North Carolina(6)"],["Oswego County, New York(7)"],["Houston County, Tennessee(6)"],["Sangamon County, Illinois(7)"],["Hernando County, Florida(6)"],["Grenada County, Mississippi(6)"],["Harrison County, Kentucky(7)"],["Tishomingo County, Mississippi(6)"],["Wolfe County, Kentucky(7)"],["Shelby County, Illinois(7)"],["Kingsbury County, South Dakota(6)"],["Carter County, Kentucky(7)"],["Humphreys County, Tennessee(6)"],["Lincoln County, West Virginia(6)"],["Webster County, West Virginia(6)"],["Cortland County, New York ...

# %% [markdown]
# ## Adjuvants
# **Recommendation: Drop adjuvant unless we have time to find more data on adjuvants.**

# %%
#create R score for cancer incidence rate per 100k and adjuvant sum

adjuvant_data_df = data_df[data_df['Adjuvant Sum'] > 0]

#r_score_filtered = adjuvant_data_df['Cancer Incidence Rate Per 100k'].corr(adjuvant_data_df['Insecticide Sum'])
#print("R score for Cancer Incidence Rate Per 100k and Insecticide Sum (where Adjuvant Sum > 0):", r_score_filtered)
print(len(adjuvant_data_df))
# Out:
# 0
