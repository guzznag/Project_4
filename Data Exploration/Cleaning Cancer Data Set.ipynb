# %%
#import libraries
import pandas as pd

# %%
#import csv
cancer_by_county_df = pd.read_csv('../Data Sets/Cancer Stats By Co. Cleaned.csv')

# %%
cancer_by_county_df.head()
# Out:
#                         County     FIPS  \
# 0            US (SEER+NPCR)(1)      0.0
# 1     Union County, Florida(6)  12125.0
# 2    Palo Alto County, Iowa(7)  19147.0
# 3  Treasure County, Montana(6)  30103.0
# 4        Polk County, Texas(7)  48373.0
#
#   Age-Adjusted Incidence Rate([rate note]) - cases per 100,000  \
# 0                                              442.3
# 1                                             1237.4
# 2                                              658.1
# 3                                              652.2
# 4                                              633.6
#
#   Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 0                           442                         442.6
# 1                        1165.6                        1312.8
# 2                         591.1                         731.1
# 3                           401                        1007.4
# 4                         604.6                         663.7
#
# ...

# %%
print(len(cancer_by_))
